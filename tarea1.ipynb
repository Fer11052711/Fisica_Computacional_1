# %% [markdown]
# <a href="https://colab.research.google.com/github/Fer11052711/Fisica_Computacional_1/blob/main/tarea1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
"""Números pares e inpares"""
n = int(input("Ingrese un numero:  "))
if n % 2 == 0:
  print("El numero es par")
else:
  print("El numero es impar")
